# %%
import pandas as pd

# %%
data = pd.read_csv('ProcessedData/br_cities_01.csv')
data.head()
# Out:
#     CAPITAL  IBGE_RES_POP  IBGE_RES_POP_ESTR  IBGE_DU_RURAL  \
# 0 -0.057359     -0.130307          -0.034666      -0.514577
# 1 -0.057359     -0.131294          -0.034666      -0.363484
# 2 -0.057359     -0.079332           0.056010      -0.024113
# 3 -0.057359     -0.039537          -0.034666      -0.257246
# 4 -0.057359      0.640114           0.002095       6.221481
#
#    IBGE_PLANTED_AREA  IBGE_CROP_PRODUCTION_$   IDHM      LONG       LAT  \
# 0          -0.316702               -0.377431  0.708 -0.498297 -0.042972
# 1          -0.222874               -0.268925  0.690 -0.179661 -0.251898
# 2          -0.091425               -0.167839  0.690 -0.385771  0.026657
# 3          -0.281900               -0.339467  0.698  0.124463 -0.332662
# 4           0.244482                4.312108  0.628 -0.411589  1.774103
#
#        AREA  ...      BEDS   Pr_Bank   Pu_Bank  Pu_Assets  Wheeled_tractor  \
# 0 -0.247349  ... -0.150991 -0.459954 -0.880516  -0.026539        -0.093247
# ...

# %%
# Extra trees with cross validation
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import cross_val_score

target_column = 'IDHM'
features = data.columns.drop(target_column)
target = data[target_column]

for n in range(20, 80, 10):
    model = ExtraTreesRegressor(n_estimators=n, max_depth=None, min_samples_split=2, min_samples_leaf=1)
    scores = cross_val_score(model, data[features], target, cv=5, scoring='r2')

    print(f"N{n}: {scores.mean()}")
# Out:
# N20: 0.8651652758147265
# N30: 0.8692677903990853
# N40: 0.8708856685661456
# N50: 0.8711739463540529
# N60: 0.8720459992795295
# N70: 0.8720821054094398
