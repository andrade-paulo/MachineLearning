# %%
import pandas as pd

# %%
data = pd.read_csv('fake_data_2.csv')
data
# Out:
#           cargo  idade  salario    bonus sócio
# 0       Diretor     45  24000.0  10000.0   sim
# 1      Analista     22   8000.0   2000.0   não
# 2   Programador     30      NaN   1000.0   não
# 3       Gerente     24  15100.0      NaN   não
# 4       Gerente     30  35000.0   6000.0   sim
# 5   Programador     22   5300.0   2000.0   não
# 6      Analista     20      NaN   1200.0   não
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %%
data.columns
# Out:
# Index(['cargo', 'idade', 'salario', 'bonus', 'sócio'], dtype='object')

# %%
lista = [1, 2, 3, 4, 5, 6]
lista[1:3]
# Out:
# [2, 3]

# %%
data['cargo'].unique()
# Out:
# array(['Diretor', 'Analista', 'Programador', 'Gerente', 'Fundador'],
#       dtype=object)

# %%
teste = data.head()

# %%
data.rename(columns={'sócio':'socio'}, inplace=True)
data
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 1      Analista     22   8000.0   2000.0   não
# 2   Programador     30      NaN   1000.0   não
# 3       Gerente     24  15100.0      NaN   não
# 4       Gerente     30  35000.0   6000.0   sim
# 5   Programador     22   5300.0   2000.0   não
# 6      Analista     20      NaN   1200.0   não
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cargo    14 non-null     object
#  1   idade    14 non-null     int64
#  2   salario  12 non-null     float64
#  3   bonus    12 non-null     float64
#  4   socio    14 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 692.0+ bytes

# %%
data.isna().sum()
# Out:
# cargo      0
# idade      0
# salario    2
# bonus      2
# socio      0
# dtype: int64

# %%
data.describe()
# Out:
#            idade       salario         bonus
# count  14.000000     12.000000     12.000000
# mean   32.928571  16795.333333   7200.000000
# std    12.499011  12355.108162   7610.996829
# min    20.000000   2344.000000   1000.000000
# 25%    25.000000   6800.000000   2000.000000
# 50%    30.000000  14550.000000   5000.000000
# 75%    34.250000  25500.000000  10000.000000
# max    65.000000  38000.000000  28000.000000

# %%
data.dropna(subset=['idade','bonus'])
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 1      Analista     22   8000.0   2000.0   não
# 2   Programador     30      NaN   1000.0   não
# 4       Gerente     30  35000.0   6000.0   sim
# 5   Programador     22   5300.0   2000.0   não
# 6      Analista     20      NaN   1200.0   não
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %%
pd.concat([data.loc[0:3], data.loc[10:12]])
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 1      Analista     22   8000.0   2000.0   não
# 2   Programador     30      NaN   1000.0   não
# 3       Gerente     24  15100.0      NaN   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim

# %%
data.iloc[0, 0]
# Out:
# 'Diretor'

# %%
data[ (data['idade'] > 25) & (data['salario'] < 10000) ]
# Out:
#           cargo  idade  salario   bonus socio
# 9      Analista     32   7300.0  4000.0   não
# 10  Programador     35   2344.0     NaN   não
# 11  Programador     28   4500.0  2200.0   não

# %%
data[ (data['idade'] > 25) & (data['salario'] > 10000) ]
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 4       Gerente     30  35000.0   6000.0   sim
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %%
data.query('idade > 25')
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 2   Programador     30      NaN   1000.0   não
# 4       Gerente     30  35000.0   6000.0   sim
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %%
a = data.dropna()
a
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 1      Analista     22   8000.0   2000.0   não
# 4       Gerente     30  35000.0   6000.0   sim
# 5   Programador     22   5300.0   2000.0   não
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %%
a.iloc[2]
# Out:
# cargo      Gerente
# idade           30
# salario    35000.0
# bonus       6000.0
# socio          sim
# Name: 4, dtype: object

# %%
data[data['cargo'].isin(['Analista', 'Programador'])]
# Out:
#           cargo  idade  salario    bonus socio
# 1      Analista     22   8000.0   2000.0   não
# 2   Programador     30      NaN   1000.0   não
# 5   Programador     22   5300.0   2000.0   não
# 6      Analista     20      NaN   1200.0   não
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 13  Programador     30  14000.0  10000.0   sim

# %%
data.query('cargo == ["Analista", "Programador"]')
# Out:
#           cargo  idade  salario    bonus socio
# 1      Analista     22   8000.0   2000.0   não
# 2   Programador     30      NaN   1000.0   não
# 5   Programador     22   5300.0   2000.0   não
# 6      Analista     20      NaN   1200.0   não
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 13  Programador     30  14000.0  10000.0   sim

# %%
data.filter(["carga", "idade", "salario"])
# Out:
#     idade  salario
# 0      45  24000.0
# 1      22   8000.0
# 2      30      NaN
# 3      24  15100.0
# 4      30  35000.0
# 5      22   5300.0
# 6      20      NaN
# 7      50  18000.0
# 8      65  38000.0
# 9      32   7300.0
# 10     35   2344.0
# 11     28   4500.0
# 12     28  30000.0
# 13     30  14000.0

# %%
data['salario'].value_counts(bins=10)
# Out:
# (2308.343, 5909.6]    3
# (5909.6, 9475.2]      2
# (13040.8, 16606.4]    2
# (34434.4, 38000.0]    2
# (16606.4, 20172.0]    1
# (23737.6, 27303.2]    1
# (27303.2, 30868.8]    1
# (9475.2, 13040.8]     0
# (20172.0, 23737.6]    0
# (30868.8, 34434.4]    0
# Name: count, dtype: int64

# %%
data.count()
# Out:
# cargo      14
# idade      14
# salario    12
# bonus      12
# socio      14
# dtype: int64

# %%
grouped = data.groupby('cargo')

# %%
grouped.groups
# Out:
# {'Analista': [1, 6, 9], 'Diretor': [0, 7], 'Fundador': [8, 12], 'Gerente': [3, 4], 'Programador': [2, 5, 10, 11, 13]}

# %%
cargos = data.groupby('cargo')[['salario', 'bonus']].sum()
cargos[cargos['salario'] == cargos['salario'].max()]
# Out:
#           salario    bonus
# cargo
# Fundador  68000.0  40000.0

# %% [markdown]
# ## Numpy

# %%
import numpy as np
